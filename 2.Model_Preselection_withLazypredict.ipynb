# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from lazypredict.Supervised import LazyClassifier

# %%
data = pd.read_csv("shopee_final.csv", encoding='utf-8')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934543 entries, 0 to 934542
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      934543 non-null  int64
#  1   processed_text  900874 non-null  object
#  2   class           934543 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 21.4+ MB

# %%
data['class'].value_counts()
# Out:
# positive    636052
# negative    186399
# neutral     112092
# Name: class, dtype: int64

# %%
df_sub= data.sample(frac=0.02)

# %%
source = df_sub['processed_text']
type(source)
# Out:
# pandas.core.series.Series

# %%
source[:5]
# Out:
# 868806      quần không_đúng cạp mặc không_đẹp hành
# 307729                hộp xịn vải dày hình xịn yêu
# 47537                                   vít ốc đít
# 598659    chất_lượng rất_tôn dáng mặc tiền tặng áo
# 595709                sản_phẩm đóng_gói chất_lượng
# Name: processed_text, dtype: object

# %%
target = df_sub['class']
type(target)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Lazy Predict with 3 class

# %%
target = target.replace("negative", 0)

# %%
target = target.replace("neutral", 1)

# %%
target = target.replace("positive", 2)

# %%
target[:5]
# Out:
# 868806    0
# 307729    2
# 47537     1
# 598659    2
# 595709    2
# Name: class, dtype: int64

# %% [markdown]
# ### tf_idf

# %%
# Create a TfidfVectorizer object
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 2), min_df=0.02)

# %%
# Fit the TfidfVectorizer object to the data
x = tfidf_vectorizer.fit(df_sub['processed_text'].values.astype('U'))

# %%
# Transform the data
X = tfidf_vectorizer.transform(df_sub['processed_text'].values.astype('U'))

# %%
### BUG: 
# This is probably because you are using an older scikit-learn version than the one this code was written for.
# get_feature_names_out is a method of the class sklearn.feature_extraction.text.TfidfVectorizer since scikit-learn 1.0. Previously, there was a similar method called get_feature_names.
# So you should update your scikit-learn package, or use the old method (not recommended).
# Create a new dataframe with the transformed data
df_new = pd.DataFrame(X.toarray(), columns=tfidf_vectorizer.get_feature_names_out())

# %%
X = X.toarray()

# %%
y = np.array(target)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|███████████████████████████████████████████| 29/29 [01:06<00:00,  2.29s/it]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# BernoulliNB                        0.57               0.54    None      0.59
# LabelSpreading                     0.71               0.54    None      0.70
# LabelPropagation                   0.71               0.54    None      0.70
# RandomForestClassifier             0.73               0.53    None      0.71
# DecisionTreeClassifier             0.70               0.53    None      0.70
# NearestCentroid                    0.47               0.53    None      0.50
# CategoricalNB                      0.51               0.53    None      0.54
# LGBMClassifier                     0.73               0.53    None      0.71
# ExtraTreesClassifier               0.72               0.53    None      0.70
# BaggingClassifier                  0.72               0.53    None      0.70
# ExtraTreeClassifier                0.70               0.53    None      0.69
# LinearDiscriminantAnalysis         0.72               0.53    None      0.71
# SGDClassifier                      0.73               0.52    None      0.70
# GaussianNB                         0.47               0.52    None      0.49
# LogisticRegression                 0.72               0.52    None      0.70
# CalibratedClassifierCV             0.72               0.51    None      0.70
# Perceptron                         0.67               0.51    None      0.67
# SVC                                0.73               0.51    None      0.70
# LinearSVC                          0.72               0.51    None      0.70
# RidgeClassifier                    0.72               0.50    None      0.70
# RidgeClassifierCV                  0.72               0.50    None      0.70
# PassiveAggressiveClassifier        0.65               0.50    None      0.65
# XGBClassifier                      0.73               0.48    None      0.69
# QuadraticDiscriminantAnalysis      0.45               0.48    None      0.47
# KNeighborsClassifier               0.69               0.46    None      0.66
# AdaBoostClassifier                 0.72               0.46    None      0.67
# DummyClassifier                    0.69               0.33    None      0.56
#
#                                Time Taken
# Model
# BernoulliNB                          0.04
# LabelSpreading                      10.02
# LabelPropagation                     4.88
# RandomForestClassifier               1.31
# DecisionTreeClassifier               0.11
# NearestCentroid                      0.04
# CategoricalNB                        0.06
# LGBMClassifier                       0.62
# ExtraTreesClassifier                 1.20
# BaggingClassifier                    0.75
# ExtraTreeClassifier                  0.04
# LinearDiscriminantAnalysis           0.11
# SGDClassifier                        0.57
# GaussianNB                           0.05
# LogisticRegression                   0.24
# CalibratedClassifierCV              23.22
# Perceptron                           0.08
# SVC                                 13.19
# LinearSVC                            6.46
# RidgeClassifier                      0.05
# RidgeClassifierCV                    0.10
# PassiveAggressiveClassifier          0.17
# XGBClassifier                        2.08
# QuadraticDiscriminantAnalysis        0.05
# KNeighborsClassifier                 0.24
# AdaBoostClassifier                   0.67
# DummyClassifier                      0.03

# %% [markdown]
# ### lazy predict with 2 class

# %%
df_sub2 = df_sub

# %%
df_sub2['class'] = df_sub2['class'].apply(lambda x: 0 if x == 'negative' or x== 'neutral' else 1 )

# %%
df_sub2['class'].value_counts()
# Out:
# 1    12731
# 0     5960
# Name: class, dtype: int64

# %%
target2 = df_sub2['class']

# %%
# Fit the TfidfVectorizer object to the data
x_2 = tfidf_vectorizer.fit(df_sub2['processed_text'].values.astype('U'))

# %%
# Transform the data
X2 = tfidf_vectorizer.transform(df_sub2['processed_text'].values.astype('U'))

# %%
X2 = X2.toarray()

# %%
y2 = np.array(target2)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, 
                                                    test_size=0.20)

# %%
models2, predictions2 = clf.fit(X_train2, X_test2, y_train2, y_test2)
# Out:
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|███████████████████████████████████████████| 29/29 [00:55<00:00,  1.92s/it]

# %%
models2
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# SVC                                0.78               0.75     0.75      0.78
# ExtraTreesClassifier               0.77               0.75     0.75      0.77
# RandomForestClassifier             0.77               0.75     0.75      0.77
# XGBClassifier                      0.77               0.75     0.75      0.77
# LGBMClassifier                     0.78               0.75     0.75      0.78
# BaggingClassifier                  0.77               0.75     0.75      0.77
# DecisionTreeClassifier             0.76               0.74     0.74      0.76
# LabelSpreading                     0.76               0.74     0.74      0.76
# LabelPropagation                   0.76               0.74     0.74      0.76
# AdaBoostClassifier                 0.77               0.74     0.74      0.77
# SGDClassifier                      0.76               0.73     0.73      0.76
# NuSVC                              0.78               0.73     0.73      0.77
# ExtraTreeClassifier                0.75               0.73     0.73      0.75
# LinearDiscriminantAnalysis         0.77               0.73     0.73      0.77
# KNeighborsClassifier               0.75               0.73     0.73      0.75
# LogisticRegression                 0.77               0.73     0.73      0.77
# LinearSVC                          0.77               0.72     0.72      0.77
# RidgeClassifier                    0.77               0.72     0.72      0.77
# RidgeClassifierCV                  0.77               0.72     0.72      0.77
# CalibratedClassifierCV             0.77               0.72     0.72      0.76
# GaussianNB                         0.61               0.70     0.70      0.60
# BernoulliNB                        0.62               0.70     0.70      0.62
# CategoricalNB                      0.62               0.70     0.70      0.62
# NearestCentroid                    0.62               0.70     0.70      0.62
# QuadraticDiscriminantAnalysis      0.58               0.68     0.68      0.57
# Perceptron                         0.69               0.58     0.58      0.65
# PassiveAggressiveClassifier        0.68               0.54     0.54      0.60
# DummyClassifier                    0.68               0.50     0.50      0.54
#
#                                Time Taken
# Model
# SVC                                 12.14
# ExtraTreesClassifier                 1.20
# RandomForestClassifier               1.39
# XGBClassifier                        0.77
# LGBMClassifier                       0.39
# BaggingClassifier                    0.63
# DecisionTreeClassifier               0.12
# LabelSpreading                       9.23
# LabelPropagation                     5.09
# AdaBoostClassifier                   0.52
# SGDClassifier                        0.20
# NuSVC                               13.72
# ExtraTreeClassifier                  0.04
# LinearDiscriminantAnalysis           0.13
# KNeighborsClassifier                 0.24
# LogisticRegression                   0.13
# LinearSVC                            2.30
# RidgeClassifier                      0.05
# RidgeClassifierCV                    0.08
# CalibratedClassifierCV               6.82
# GaussianNB                           0.04
# BernoulliNB                          0.04
# CategoricalNB                        0.05
# NearestCentroid                      0.04
# QuadraticDiscriminantAnalysis        0.06
# Perceptron                           0.06
# PassiveAggressiveClassifier          0.07
# DummyClassifier                      0.03

# %% [markdown]
# ### Resampling

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE

# %%
smt = SMOTE()
X_smt, y_smt = smt.fit_resample(X,y)

# %%
X_train_smt, X_test_smt, y_train_smt, y_test_smt = train_test_split(X_smt, y_smt, 
                                                    test_size=0.20)

# %% [markdown]
# ### SMOTE for 3 classes

# %%
models_smt, predictions_smt = clf.fit(X_train_smt, X_test_smt, y_train_smt, y_test_smt)
# Out:
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|███████████████████████████████████████████| 29/29 [06:54<00:00, 14.29s/it]

# %%
models_smt
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.69               0.69    None      0.69
# RandomForestClassifier             0.68               0.68    None      0.68
# LabelPropagation                   0.68               0.68    None      0.68
# LabelSpreading                     0.68               0.68    None      0.68
# BaggingClassifier                  0.67               0.68    None      0.68
# XGBClassifier                      0.66               0.66    None      0.66
# ExtraTreeClassifier                0.66               0.66    None      0.66
# DecisionTreeClassifier             0.66               0.66    None      0.66
# LGBMClassifier                     0.66               0.66    None      0.66
# NuSVC                              0.65               0.65    None      0.65
# SVC                                0.63               0.63    None      0.63
# KNeighborsClassifier               0.62               0.62    None      0.62
# AdaBoostClassifier                 0.60               0.60    None      0.60
# CalibratedClassifierCV             0.59               0.59    None      0.59
# LogisticRegression                 0.59               0.59    None      0.59
# RidgeClassifier                    0.59               0.59    None      0.59
# RidgeClassifierCV                  0.59               0.59    None      0.59
# LinearSVC                          0.59               0.59    None      0.59
# LinearDiscriminantAnalysis         0.59               0.59    None      0.59
# SGDClassifier                      0.56               0.56    None      0.54
# NearestCentroid                    0.54               0.54    None      0.53
# Perceptron                         0.53               0.53    None      0.53
# PassiveAggressiveClassifier        0.51               0.52    None      0.51
# GaussianNB                         0.51               0.51    None      0.48
# BernoulliNB                        0.51               0.51    None      0.51
# QuadraticDiscriminantAnalysis      0.47               0.47    None      0.42
# DummyClassifier                    0.33               0.33    None      0.16
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 2.89
# RandomForestClassifier               3.26
# LabelPropagation                    22.22
# LabelSpreading                      60.29
# BaggingClassifier                    1.51
# XGBClassifier                        4.04
# ExtraTreeClassifier                  0.09
# DecisionTreeClassifier               0.26
# LGBMClassifier                       0.79
# NuSVC                              153.41
# SVC                                 70.49
# KNeighborsClassifier                 0.58
# AdaBoostClassifier                   1.21
# CalibratedClassifierCV              69.05
# LogisticRegression                   0.56
# RidgeClassifier                      0.11
# RidgeClassifierCV                    0.18
# LinearSVC                           21.18
# LinearDiscriminantAnalysis           0.27
# SGDClassifier                        1.03
# NearestCentroid                      0.08
# Perceptron                           0.19
# PassiveAggressiveClassifier          0.30
# GaussianNB                           0.09
# BernoulliNB                          0.09
# QuadraticDiscriminantAnalysis        0.12
# DummyClassifier                      0.06

# %%
X_smt2, y_smt2 = smt.fit_resample(X2,y2)

# %%
X_train_smt2, X_test_smt2, y_train_smt2, y_test_smt2 = train_test_split(X_smt2, y_smt2, 
                                                    test_size=0.20)

# %%
models_smt2, predictions_smt2 = clf.fit(X_train_smt2, X_test_smt2, y_train_smt2, y_test_smt2)
# Out:
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|███████████████████████████████████████████| 29/29 [01:47<00:00,  3.70s/it]

# %% [markdown]
# ### SMOTE for 2 CLasses

# %%
models_smt2
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.80               0.80     0.80      0.80
# RandomForestClassifier             0.80               0.80     0.80      0.79
# LGBMClassifier                     0.79               0.79     0.79      0.79
# XGBClassifier                      0.79               0.79     0.79      0.79
# BaggingClassifier                  0.79               0.79     0.79      0.79
# LabelPropagation                   0.78               0.79     0.79      0.78
# LabelSpreading                     0.78               0.79     0.79      0.78
# SVC                                0.78               0.79     0.79      0.78
# ExtraTreeClassifier                0.78               0.78     0.78      0.78
# DecisionTreeClassifier             0.78               0.78     0.78      0.78
# NuSVC                              0.78               0.78     0.78      0.77
# KNeighborsClassifier               0.78               0.78     0.78      0.78
# AdaBoostClassifier                 0.77               0.77     0.77      0.77
# LinearSVC                          0.77               0.77     0.77      0.77
# LogisticRegression                 0.77               0.77     0.77      0.77
# LinearDiscriminantAnalysis         0.77               0.77     0.77      0.77
# RidgeClassifier                    0.77               0.77     0.77      0.77
# RidgeClassifierCV                  0.77               0.77     0.77      0.77
# CalibratedClassifierCV             0.77               0.77     0.77      0.77
# SGDClassifier                      0.75               0.75     0.75      0.75
# PassiveAggressiveClassifier        0.71               0.71     0.71      0.70
# QuadraticDiscriminantAnalysis      0.69               0.70     0.70      0.68
# GaussianNB                         0.69               0.70     0.70      0.67
# BernoulliNB                        0.68               0.69     0.69      0.66
# Perceptron                         0.68               0.68     0.68      0.67
# NearestCentroid                    0.66               0.67     0.67      0.63
# DummyClassifier                    0.49               0.50     0.50      0.32
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 1.89
# RandomForestClassifier               2.03
# LGBMClassifier                       0.35
# XGBClassifier                        0.98
# BaggingClassifier                    0.96
# LabelPropagation                     9.85
# LabelSpreading                      19.87
# SVC                                 20.12
# ExtraTreeClassifier                  0.08
# DecisionTreeClassifier               0.20
# NuSVC                               29.67
# KNeighborsClassifier                 0.35
# AdaBoostClassifier                   0.71
# LinearSVC                            3.93
# LogisticRegression                   0.18
# LinearDiscriminantAnalysis           0.17
# RidgeClassifier                      0.07
# RidgeClassifierCV                    0.11
# CalibratedClassifierCV              15.07
# SGDClassifier                        0.26
# PassiveAggressiveClassifier          0.08
# QuadraticDiscriminantAnalysis        0.08
# GaussianNB                           0.07
# BernoulliNB                          0.07
# Perceptron                           0.06
# NearestCentroid                      0.05
# DummyClassifier                      0.06

# %% [markdown]
# ## Kết luận

# %% [markdown]
# - đối với mô hình sử dụng 3 biến, ta sẽ không sử dụng resampling do kết quả không đuọc cải thiện
# - đối với mô hình 2 biến thì chúng ta sẽ resampling do kết quae được cải thiện rất tốt

# %% [markdown]
# #### Model preslection
# - dựa trên tiêu chi theo thứ tự Accuracy và time, sau đó là ROC và F1

# %% [markdown]
# ##### đối với 3 class
# - RandomForestClassifier
# - KNeighborsClassifier
# - LogisticRegression

# %% [markdown]
# ##### đối với 2 class
# - ExtraTreesClassifier
# - XGBClassifier
# - LogisticRegression
# - KNeighborsClassifier
